# %%
# How to import
import pandas as pd

# %% [markdown]
# ## DataFrame:
#     - 2D
#     - Single sheet (all rows and colums)
#     - Table
#     - Matrix
# ## Series
#     - 1D
#     - Column (similar to a single column of data)
#     - Column
#     - Column Vector
#
# ## Helpful figure
# ![image.png](attachment:c6f6f6fa-8161-4805-ae4b-ccb3587c0231.png)
#
# ## Exercises:
